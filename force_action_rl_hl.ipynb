# %% [markdown]
# ### Problem statment
#
# Let's suppose, thzt some object - victim has constant trajectiory. Next, there is an other object - hunter. The goal of hunter is to watch the victim. More specificly to be on a given target distance from victim with given a accuracy.
# Hunter problem is that he knows restricted amount of information:
#
# 1. Is hunter close in on the victim: $\{0,1\}$
#
# 2. Is hunter on target distance with given accuracy: $\{0,1\}$
#
# 3. Dirrection of victim velocity $v_{v}$: $\frac{v_{v}}{||v_{v}||}$
#
# 4. Dirrection of hunter velocity $v_{v}$: $\frac{v_{h}}{||v_{h}||}$
#
# 5. Hunter force: $f_{h}$
#
# In descrete time case hunter will have the following information:
#
# 1. Is hunter close in on the victim: $h\left(\left|\left|x_{h}^{-1}-x_{v}^{-1}\right|\right|-\left|\left|x_{h}^0-x_{v}^0\right|\right|\right)$
#
# 2. Is hunter on target distance $d_t$ with given accuracy $e_t$: $h \left(\left|\,\left|\left|x_{h}^0-x_{v}^0\right|\right|-d_t \,\right|- e_t\right)$
#
# 3. Dirrection of victim velocity: $\frac{x_{v}^0 - x_{v}^{-1}}{||x_{v}^0 - x_{v}^{-1}||}$
#
# 3. Dirrection of hunter velocity: $\frac{x_{h}^0 - x_{h}^{-1}}{||x_{h}^0 - x_{h}^{-1}||}$
#
# 4. Hunter force: $f_{h}^{-1}$

# %% [markdown]
# ### Environment

# %% [markdown]
# ### Hunter policy
#
# Since hunter may moove only with speed constrained by some constant, we need to
# constrain action space. Let's define max speed as $v_{max}$.
# We may define our distribution via some function $G(x)$ from simple normal distribution $\mathcal{N}(x|\mu,diag(e^{2 s}))$.
# Let's define function $g(x)$ so, that it was constrained in circle with radius $v_{max}$:
# $$
# G(x) = v_{max}\frac{x}{||x||_2}e^{-||x||_2^2}
# $$
#
# $$\nabla_x\left[\textbf{f}(x)g(x)\right] = \frac{d\textbf{f}(x)}{dx}g(x)+\frac{dg(x)}{dx} \textbf{f}(x)^T $$
#
# $$ \nabla_x G(x) =v_{max} \left( \frac{e^{-||x||_2^2}}{||x||_2} I + \nabla_x\left[\frac{e^{-||x||_2^2}}{||x||_2}\right]x^T\right) $$

# %% [markdown]
# $$ \nabla_x\left[\frac{e^{-||x||_2^2}}{||x||_2}\right] = \nabla_{||x||_2}\left[\frac{e^{-||x||_2^2}}{||x||_2}\right]\nabla_x||x||_2$$
#
# $$\nabla_x||x||_2 = \frac{x}{||x||_2}$$
# $$  \nabla_{||x||_2}\left[\frac{e^{-||x||_2^2}}{||x||_2}\right] = -\left[\frac{1}{||x||_2^2}+2\right]e^{-||x||_2^2}$$

# %% [markdown]
# $$ \nabla_x G(x) =v_{max}\frac{e^{-||x||_2^2}}{||x||_2} \left(I -\left[\frac{1}{||x||_2^2}+2\right] x x^T\right)  $$

# %% [markdown]
# $$\mathcal{J}_{G(x)}=-\left(v_{max} \frac{e^{-||x||_2^2}}{||x||_2}\right)^n \left(1-\left[\frac{1}{||x||_2^2}+2\right]||x||_2^2 \right) = 2\left(v_{max} \frac{e^{-||x||_2^2}}{||x||_2}\right)^n ||x||_2^2 $$

# %% [markdown]
# for 2 dimentions:
# $$\mathcal{J}_{G(x)}=2 v_{max}^2 e^{-2||x||_2^2}$$

# %% [markdown]
# $$\ln(\mathcal{J}_{G(x)}^{-1})=2\left(||x||_2^2-\ln v_{max}\right)-\ln 2$$

# %% [markdown]
# So, PDF of distribution rv G(x) may be estimated as following:
# $$\mathcal{N}(x|\mu,diag(e^{2s}))J_{G(x)}^{-1}$$

# %%
import torch
import numpy as np
from policy import HunterPolicy, VictimPolicy,Baseline
from environment import ForceHunterEnvironment

from train import train, visualize
# %matplotlib inline
victim_policy = lambda t: np.array([0,0])
# victim_policy = VictimPolicy.ellipse_victim_policy
env = ForceHunterEnvironment(victim_policy)#,energy_loss = lambda f: np.linalg.norm(f)*5)
baseline = Baseline(env)
policy = HunterPolicy(env,max_action=3)

# %%
train(policy,env,100000,learning_rate=0.0001,baseline = baseline, visualize = visualize)
# Out:
# Episode 1870 	Last reward: 944.00
# Last reward: 9.45
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b0c46855330d> in <module>()
# ----> 1 train(policy,env,100000,learning_rate=0.0001,baseline = baseline, visualize = visualize)
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/train.py in train(policy, env, episodes, learning_rate, gamma, verbose, save_policy, batch, visualize, baseline, dirpath)
#     183     for episode in range(0, episodes):
#     184         env.reset() # Reset environment and record the starting state
# --> 185         play_episode(policy, env, baseline)
#     186
#     187         values = compute_value_function(policy, gamma)
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/train.py in play_episode(policy, env, baseline)
#      68     """play one episode from the initial point"""
#      69     for time in range(1000):
# ---> 70         action = select_action(policy, env.state)
#      71
#      72         #baseline update
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/train.py in select_action(policy, state)
#      12     #Select an action (0 or 1) by running policy model and choosing based on the probabilities in state
#      13     _,_ = policy(torch.Tensor(state)) #state_mu,state_logsigma
# ---> 14     action,log_prob = policy.sample_action()
#      15     # Add log probability of our chosen action to our history
#      16     if policy.policy_history.dim() != 0:
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/policy.py in sample_action(self)
#      41     def sample_action(self):
#      42         latent_action = self.latent_action_dist.sample()
# ---> 43         action = self.get_action(latent_action)
#      44         return action, self.log_prob(latent_action)
#      45
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/policy.py in get_action(self, latent_action)
#      27
#      28     def get_action(self,latent_action):
# ---> 29         action = self.max_action*latent_action*(torch.exp(-(latent_action**2).sum(dim = -1))/torch.norm(latent_action,dim = -1)).unsqueeze(-1)
#      30         return action
#      31
#
# KeyboardInterrupt:

# %%
policy = torch.load('force_policy_ellipse_max_action_3.p')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/serialization.py:425: SourceChangeWarning: source code of class 'policy.HunterPolicy' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
# torch.save(policy,'force_policy_ellipse_max_action_3_energy_loss_f*5.p')
policy = torch.load('force_policy_ellipse_max_action_3.p')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/serialization.py:425: SourceChangeWarning: source code of class 'policy.HunterPolicy' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %% [markdown]
# ### Test Visualization

# %%
from visualization import model_hunter_learning
# %matplotlib notebook


model_hunter_learning('Test. max action = 3',policy,env,hunter_start_position=[10,10])
# Out:
# <img src="data:image/png;base64,..." width="720">
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_base.py:2961: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b7b5662471b7> in <module>()
#       3
#       4
# ----> 5 model_hunter_learning('Test. max action = 3',policy,env,hunter_start_position=[10,10])
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/visualization.py in model_hunter_learning(name, policy, env, hunter_start_position)
#      63         rewards = np.append(rewards,reward)
#      64         state = env.state
# ---> 65         update_graph(graph,np.array(env.hunter_trajectory).T,np.array(env.victim_trajectory).T,rewards)
#      66
#      67
#
# ~/Yandex.Disk.localized/Files/Skoltech/Thesis/Hunter Learning/hunter_learning/visualization.py in update_graph(graph, hunter_trajectoty, victim_trajectoty, rewards)
#      47     ax_reward.set_xlim(np.arange(len(rewards)).min(),np.arange(len(rewards)).max())
#      48     ax_reward.set_ylim(rewards.min()-1,rewards.max()+1)
# ---> 49     fig.canvas.draw()
#      50
#      51
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     163             backend_agg.RendererAgg.lock.release()
#     164             # Swap the frames
# --> 165             self.manager.refresh_all()
#     166
#     167     def draw_idle(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in refresh_all(self)
#     455     def refresh_all(self):
#     456         if self.web_sockets:
# --> 457             diff = self.canvas.get_diff_image()
#     458             if diff is not None:
#     459                 for s in self.web_sockets:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in get_diff_image(self)
#     213             buff = _png.write_png(
#     214                 output.view(dtype=np.uint8).reshape(output.shape + (4,)),
# --> 215                 None, compression=6, filter=_png.PNG_FILTER_NONE)
#     216
#     217             # Swap the renderer frames
#
# KeyboardInterrupt:
