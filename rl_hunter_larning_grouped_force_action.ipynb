# %% [markdown]
# ### Problem statment
#
# Let's suppose, that there are a grup of objects - hunters. The goal of each hunter is to follow the group and be  be at a given target distance from  neighbour hunters with given a accuracy.
# Hunter problem is that he knows restricted amount of information:
#
#
#
# 1. Dirrection of closest hunter velocity $v_{c}$: $\frac{v_{c}}{||v_{c}||}$
# 2. Does hunter distance to closest hunter reduced: $\{0,1\}$
# 3. Is closest hunter at the target distance with given accuracy: $\{0,1\}$
# 4. Dirrection of group velocity $v_{g}$: $\frac{v_{g}}{||v_{g}||}$
# 5. Does hunter distance to group center reduced: $\{0,1\}$
# 6. Dirrection of hunter velocity $v_{h}$: $\frac{v_{h}}{||v_{h}||}$
# 7. Hunter force: $f_{h}$
#
# In descrete time case hunter will have the following information:
#
# 1. Dirrection of closest hunter velocity: $\frac{x_{h_{c}}^0 - x_{h_{c}}^{-1}}{||x_{h_{c}}^0 - x_{h_{c}}^{-1}||}$
#
#     $ c = arg \min\limits_{k\ne i} \left|\left|x_{h_i}^{-1}-x_{h_k}^{-1}\right|\right|$
#
# 2. Does hunter distance to closest neighbour hunter reduced: $h\left(d_i^{0}- d_i^{1}\right)$
#
#     $ d_i^{-1} = \min\limits_{k\ne i} \left|\left|x_{h_i}^{-1}-x_{h_k}^{-1}\right|\right|$
#
#     $ d_i^{0} = \min\limits_{k\ne i} \left|\left|x_{h_i}^{0}-x_{h_k}^{0}\right|\right|$
#
# 3. Is closest hunter at the target distance $d_t$ with given accuracy $e_t$: $h \left(\left|\,\left|\left|x_{h}^0-x_{c}^0\right|\right|-d_t \,\right|- e_t\right)$
#
# 4. Dirrection of group velocity: $\frac{x_{g}^0 - x_{g}^{-1}}{||x_{g}^0 - x_{g}^{-1}||}$
#
#     $x_g^{-1} = \overline{x_h}^{-1}$
#
#     $x_g^{0} = \overline{x_h}^{0}$
#
# 5. Does hunter distance to group center reduced: $h\left(\left|\left|x_{h}^{-1}-x_{g}^{-1}\right|\right|-\left|\left|x_{h}^0-x_{g}^0\right|\right|\right)$
#
# 6. Dirrection of hunter velocity: $\frac{x_{h_i}^0 - x_{h_i}^{-1}}{||x_{h_i}^0 - x_{h_i}^{-1}||}$
#
# 7. Hunter force: $f_{h_i}^{-1}$

# %% [markdown]
# ### Environment

# %% [markdown]
# #### Hunter policy
#
# Since hunter may moove only with speed constrained by some constant, we need to
# constrain action space. Let's define max speed as $v_{max}$.
# We may define our distribution via some function $G(x)$ from simple normal distribution $\mathcal{N}(x|\mu,diag(e^{2 s}))$.
# Let's define function $g(x)$ so, that it was constrained in circle with radius $v_{max}$:
# $$
# G(x) = v_{max}\frac{x}{||x||_2}e^{-||x||_2^2}
# $$
#
# $$\nabla_x\left[\textbf{f}(x)g(x)\right] = \frac{d\textbf{f}(x)}{dx}g(x)+\frac{dg(x)}{dx} \textbf{f}(x)^T $$
#
# $$ \nabla_x G(x) =v_{max} \left( \frac{e^{-||x||_2^2}}{||x||_2} I + \nabla_x\left[\frac{e^{-||x||_2^2}}{||x||_2}\right]x^T\right) $$

# %% [markdown]
# $$ \nabla_x\left[\frac{e^{-||x||_2^2}}{||x||_2}\right] = \nabla_{||x||_2}\left[\frac{e^{-||x||_2^2}}{||x||_2}\right]\nabla_x||x||_2$$
#
# $$\nabla_x||x||_2 = \frac{x}{||x||_2}$$
# $$  \nabla_{||x||_2}\left[\frac{e^{-||x||_2^2}}{||x||_2}\right] = -\left[\frac{1}{||x||_2^2}+2\right]e^{-||x||_2^2}$$

# %% [markdown]
# $$ \nabla_x G(x) =v_{max}\frac{e^{-||x||_2^2}}{||x||_2} \left(I -\left[\frac{1}{||x||_2^2}+2\right] x x^T\right)  $$

# %% [markdown]
# $$\mathcal{J}_{G(x)}=-\left(v_{max} \frac{e^{-||x||_2^2}}{||x||_2}\right)^n \left(1-\left[\frac{1}{||x||_2^2}+2\right]||x||_2^2 \right) = 2\left(v_{max} \frac{e^{-||x||_2^2}}{||x||_2}\right)^n ||x||_2^2 $$

# %% [markdown]
# for 2 dimentions:
# $$\mathcal{J}_{G(x)}=2 v_{max}^2 e^{-2||x||_2^2}$$

# %% [markdown]
# $$\ln(\mathcal{J}_{G(x)}^{-1})=2\left(||x||_2^2-\ln v_{max}\right)-\ln 2$$

# %% [markdown]
# So, PDF of distribution rv G(x) may be estimated as following:
# $$\mathcal{N}(x|\mu,diag(e^{2s}))J_{G(x)}^{-1}$$

# %% [markdown]
# #### Reward assignmend
#
# Reword is equal to:
#
#     if closest hunter at the target distence: 1
#
#     else, if distance to closest huter reduced: 0
#
#     else: -1

# %%
import torch
from policy import HunterPolicy, VictimPolicy, Baseline
from environment import GroupedHunterEnvironment

from train import train, visualize_group
# %matplotlib inline

env = GroupedHunterEnvironment()

baseline = Baseline(env)
policy = HunterPolicy(env,max_action=3)

# %%
class

# %%
train(policy,env,100000, learning_rate=0.0001, baseline=baseline)
# Out:
# Episode 810 	Last reward: 1324.00
# Last reward: 1.23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c7f6bf58fe6b> in <module>()
# ----> 1 train(policy,env,100000, learning_rate=0.0001, baseline=baseline)
#
# ~/Documents/living_system/train.py in train(policy, env, episodes, learning_rate, gamma, verbose, save_policy, batch, visualize, baseline)
#     184     for episode in range(0, episodes):
#     185         env.reset() # Reset environment and record the starting state
# --> 186         play_episode(policy, env, baseline)
#     187
#     188         values = compute_value_function(policy, gamma)
#
# ~/Documents/living_system/train.py in play_episode(policy, env, baseline)
#      79         # Step through environment using chosen action
#      80         # conmpute reward, renew state
# ---> 81         reward = env.step(action)
#      82         # Save reward
#      83         policy.reward_episode.append(reward)
#
# ~/Documents/living_system/environment.py in step(self, action)
#     268         self.update_shifts()
#     269         self.update_positions()
# --> 270         self.update_state()
#     271         reward = self.get_reward()
#     272         return reward
#
# ~/Documents/living_system/environment.py in update_state(self)
#     315         self.distances_to_center = new_distances_to_center
#     316
# --> 317         shift_is_zero = (self.hunter_shift == 0) * (np.flip(self.hunter_shift,1) == 0)
#     318         hunter_shift = np.where(shift_is_zero,np.random.rand(self.num_hunters,2),self.hunter_shift)
#     319         normalized_hunter_shift = hunter_shift/(np.linalg.norm(hunter_shift,axis = 1)[:,np.newaxis])
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in flip(m, axis)
#     231         indexer = (np.s_[::-1],) * m.ndim
#     232     else:
# --> 233         axis = _nx.normalize_axis_tuple(axis, m.ndim)
#     234         indexer = [np.s_[:]] * m.ndim
#     235         for ax in axis:
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1510     """
#    1511     try:
# -> 1512         axis = [operator.index(axis)]
#    1513     except TypeError:
#    1514         axis = tuple(axis)
#
# KeyboardInterrupt:

# %%
policy = torch.load('force_policy_ellipse_max_action_3.p')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-54ecbb2f3824> in <module>()
# ----> 1 policy = torch.load('force_policy_ellipse_max_action_3.p')
#
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     299             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     300         new_fd = True
# --> 301         f = open(f, 'rb')
#     302     try:
#     303         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'force_policy_ellipse_max_action_3.p'

# %%
torch.save(policy,'new_force_policy_ellipse_max_action_3.p')
policy = torch.load('new_force_policy_ellipse_max_action_3.p')

# %% [markdown]
# ### Test Visualization

# %%
from grouped_visualization import model_hunter_learning
# %matplotlib notebook

             

model_hunter_learning('Test. max action = 3',policy,env)
# Out:
# <img src="data:image/png;base64,..." width="719.999989271164">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-91d5764f47be> in <module>()
#       4
#       5
# ----> 6 model_hunter_learning('Test. max action = 3',policy,env)
#
# ~/Documents/living_system/grouped_visualization.py in model_hunter_learning(name, policy, env, hunter_start_position)
#      77 #         ema_rewards = np.append(ema_rewards,a* ema_rewards[-1] + (1-a)*reward)
#      78         state = env.state
# ---> 79         update_graph(graph,env.hunter_trajectory,env.group_trajectory,rewards)
#
# ~/Documents/living_system/grouped_visualization.py in update_graph(graph, hunter_trajectory, group_tragectory, rewards)
#      58         ax_model.set_xlim(x.min()-dx,x.max()+dx)
#      59         ax_model.set_ylim(y.min(),y.max())
# ---> 60     fig.canvas.draw()
#      61
#      62
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     159         backend_agg.RendererAgg.lock.acquire()
#     160         try:
# --> 161             self.figure.draw(renderer)
#     162         finally:
#     163             backend_agg.RendererAgg.lock.release()
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/legend.py in draw(self, renderer)
#     780                 shadow.draw(renderer)
#     781
# --> 782             self.legendPatch.draw(renderer)
#     783
#     784         self._legend_box.draw(renderer)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/patches.py in draw(self, renderer)
#     542             renderer = PathEffectRenderer(self.get_path_effects(), renderer)
#     543
# --> 544         renderer.draw_path(gc, tpath, affine, rgbFace)
#     545
#     546         gc.restore()
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     163         else:
#     164             try:
# --> 165                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     166             except OverflowError:
#     167                 raise OverflowError("Exceeded cell block limit (set 'agg.path.chunksize' rcparam)")
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in get_dashes(self)
#     938         return None, None
#     939
# --> 940     def get_dashes(self):
#     941         """
#     942         Return the dash information as an offset dashlist tuple.
#
# KeyboardInterrupt:
